# %%
print("hello")
# Out:
# hello

# %%
import math
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

def f(x):
    return 3*x**2-4*x+5
print(f(3.0))
# Out:
# 20.0

# %%
xs=np.arange(-5, 5, 0.25)
ys=f(xs)
plt.plot(xs, ys)

# %%
h = 0.000000001
x=3.0
(f(x+h)-f(x))/h
# Out:
# 14.000001158365194

# %%
a = 2.0
b = -3.0
c = 10.0
d = a*b + c
print(d)
# Out:
# 4.0

# %%
h = 0.0001
a = 2.0
b = -3.0
c = 10.0
d1 = a*b + c
a+= h 
d2 = a*b + c
print('d1' , d1)
print('d2' , d2)
print('slope' , (d2-d1)/h)
# Out:
# d1 4.0
# d2 3.999699999999999
# slope -3.000000000010772

# %%
class Value:
    def __init__(self, data, _children=(), _op='', label=''):
        self.data = data
        self.grad = 0.0
        self._backward = lambda: None
        self._prev = set(_children)
        self._op = _op
        self.label = label

    def __repr__(self):
        return f"Value(data={self.data}, grad={self.grad})"

    def __add__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(self.data + other.data, (self, other), '+')
        
        def _backward():
            self.grad += 1.0 * out.grad
            other.grad += 1.0 * out.grad
        out._backward = _backward
        return out

    def __radd__(self, other): # Handles scalar + Value (e.g., 2 + a)
        return self + other

    def __mul__(self, other):
        other = other if isinstance(other, Value) else Value(other)
        out = Value(self.data * other.data, (self, other), '*')
        
        def _backward():
            self.grad += other.data * out.grad   # Fixed: Changed = to +=
            other.grad += self.data * out.grad   # Fixed: Changed = to +=
        out._backward = _backward
        return out

    def __rmul__(self, other):
        return self * other

    def __pow__(self, other):
        assert isinstance(other, (int, float)), "only supporting int/float powers for now"
        out = Value(self.data**other, (self,), f'**{other}')

        def _backward():
            self.grad += other * (self.data ** (other - 1)) * out.grad
        out._backward = _backward
        return out

    def __truediv__(self, other):
        return self * (other**-1)

    def __rtruediv__(self, other):
        return Value(other) * (self**-1)

    def __neg__(self):
        return self * -1

    def __sub__(self, other):
        return self + (-other)

    def __rsub__(self, other):
        return Value(other) + (-self)

    def tanh(self):
        x = self.data
        t = (math.exp(2*x) - 1) / (math.exp(2*x) + 1)
        out = Value(t, (self,), 'tanh')
        
        def _backward():
            self.grad += (1 - t**2) * out.grad   # Fixed: Changed = to +=
        out._backward = _backward
        return out

    def exp(self):
        x = self.data
        out = Value(math.exp(x), (self,), 'exp')
        
        def _backward():                          # Fixed: Fixed typo (bacward -> _backward)
            self.grad += out.data * out.grad
        out._backward = _backward                 # Fixed: Correct closure reference
        return out

    def backward(self):
        # Properly indented topological sort
        topo = []
        visited = set()
        
        def build_topo(v):
            if v not in visited:
                visited.add(v)
                for child in v._prev:
                    build_topo(child)
                topo.append(v)
                
        build_topo(self)
        
        self.grad = 1.0
        for node in reversed(topo):
            node._backward()

# %%
d._prev
# Out:
# {Value(data=-6.0), Value(data=10.0)}

# %%
d._op
a = Value(2.0)
b = Value(4.0)#        other = other if isinstance(other, Value) else Value(other) due to this we can add or multiply here

a+1
a * 2
a.exp()
a / b
a - b
# Out:
# Value(data=-2.0)

# %%
from graphviz import Digraph

def trace(root):
    nodes, edges = set(), set()

    def build(v):
        if v not in nodes:
            nodes.add(v)
            for child in v._prev:
                edges.add((child, v))
                build(child)

    build(root)
    return nodes, edges


def draw_dot(root):
    dot = Digraph(format='svg', graph_attr={'rankdir': 'LR'})

    nodes, edges = trace(root)

    for n in nodes:
        uid = str(id(n))

        dot.node(
            name=uid,
            label="{ %s| data %.4f | grad %.4f }" % (n.label, n.data, n.grad),
            shape="record"
        )

        if n._op:
            dot.node(name=uid + n._op, label=n._op)
            dot.edge(uid + n._op, uid)

    for n1, n2 in edges:
        dot.edge(str(id(n1)), str(id(n2)) + n2._op)

    return dot

# %%
draw_dot(L)

# %%
L.grad=1.0#dL/dL=1
draw_dot(L)

# %%
#dL/dF=d as l=f*d and dL/dD=f same logic
f.grad=4.00
d.grad=-2.00
draw_dot(L)

# %%
def lol():
    h=0.001
    
a = Value(2.0, label='a')
b = Value(-3.0, label='b')
c = Value(10.0, label='c')
e=a*b; e.label = 'e'
d = e + c; d.label = 'd'
f = Value(-2.0, label='f')
L = d*f;L.label='L'
L1=L.data

h=0.001

a = Value(2.0, label='a')
b = Value(-3.0, label='b')
c = Value(10.0, label='c')
e=a*b; e.label = 'e'
d = e + c; d.label = 'd'
f = Value(-2.0+h, label='f')
L = d*f;L.label='L'
L2=L.data

print((L2-L1)/h)  #gradient check
# Out:
# 3.9999999999995595

# %%
#dd/dc=1.0
#dd/de=1.0 we need dl/dc and dl/de
#we need dL/dc and dL.de  using chain rule we can get both dL/dc=dL/dD*dD/dc and same for other
c.grad=-2.0
e.grad=-2.0
draw_dot(L)

# %%
#dL/da=dL/de*de/da and same for dL/db using chain rule
#dL/da=-2*-3=6
#dL/db=-2*2=-4
a.grad=6.0
b.grad=-4.0
draw_dot(L)

# %%
a.data+=0.01*a.grad
b.data+=0.01*b.grad
c.data+=0.01*c.grad
f.data+=0.01*f.grad
e=a*b
d=e+c
L=d*f
print(L.data)
# Out:
# -7.4314824

# %%
plt.plot(np.arange(-5,5,0.2), np.tanh(np.arange(-5,5,0.2)));plt.grid()

# %%
#inputs x1,x2
x1=Value(2.0, label='x1')
x2=Value(0.0, label='x2')
#weights w1,w2
w1=Value(-3.0, label='w1')
w2=Value(1.0, label='w2')
#bias of the neuron
b=Value(6.8813735870195432, label='b')
#x1*w2 +x2*w2
x1w1 = x1*w1; x1w1.label = 'x1*w1'
x2w2 = x2*w2; x2w2.label = 'x2*w2'
x1w1x2w2 = x1w1 + x2w2; x1w1x2w2.label = 'x1*w1 + x2*w2'
n = x1w1x2w2 + b; n.label = 'n'
o = n.tanh(); o.label = 'o'

# %%
o.grad = 1.0
draw_dot(o)
#inputs x1,x2
x1=Value(2.0, label='x1')
x2=Value(0.0, label='x2')
#weights w1,w2
w1=Value(-3.0, label='w1')
w2=Value(1.0, label='w2')
#bias of the neuron
b=Value(6.8813735870195432, label='b')
#x1*w2 +x2*w2
x1w1 = x1*w1; x1w1.label = 'x1*w1'
x2w2 = x2*w2; x2w2.label = 'x2*w2'
x1w1x2w2 = x1w1 + x2w2; x1w1x2w2.label = 'x1*w1 + x2*w2'
n = x1w1x2w2 + b; n.label = 'n'
e = (2*n).exp()
o = (e-1) / (e+1)
o.label= 'o'
o.backward()
draw_dot(o)

# %%
#o = tanhh(n)
#do.dn=1-tanhh(n)^2=1-o**2 value of o=0.707
#do/dn=0.5
n.grad = 0.5
draw_dot(o)

# %%
#because of +
#b.grad=x1w1x2w2.grad=0.5
#as there is + sign again 
#x1*w1.grad=x2*w2.grad=0.5
b.grad=0.5
x1w1x2w2.grad=0.5
x1w1.grad=0.5
x2w2.grad=0.5
draw_dot(o)

# %%
x2.grad = w2.data * x2w2.grad#chain rule
w2.grad = x2.data * x2w2.grad
draw_dot(o)

# %%
x1.grad = w1.data * x1w1.grad#chain rule
w1.grad = x1.data * x1w1.grad
draw_dot(o)

# %%
draw_dot(o)

# %%
o.grad = 1.0
o._backward()
n._backward()
b._backward()
x1w1x2w2._backward()
x2w2._backward()
x1w1._backward()

draw_dot(o)

# %%
topo = []
visited = set()
def build_topo(v):
    if v not in visited:
        visited.add(v)
        for child in v._prev:
            build_topo(child)
        topo.append(v)
    build_topo(0)
    topo

# %%
o.grad = 1.0
topo = []
visited = set()
def build_topo(v):
    if v not in visited:
        visited.add(v)
        for child in v._prev:
            build_topo(child)
        topo.append(v)
    build_topo(0)
    for node in reversed(topo):
        node._backward()


draw_dot(o)

# %%
o.grad = 1.0
draw_dot(o)
#inputs x1,x2
x1=Value(2.0, label='x1')
x2=Value(0.0, label='x2')
#weights w1,w2
w1=Value(-3.0, label='w1')
w2=Value(1.0, label='w2')
#bias of the neuron
b=Value(6.8813735870195432, label='b')
#x1*w2 +x2*w2
x1w1 = x1*w1; x1w1.label = 'x1*w1'
x2w2 = x2*w2; x2w2.label = 'x2*w2'
x1w1x2w2 = x1w1 + x2w2; x1w1x2w2.label = 'x1*w1 + x2*w2'
n = x1w1x2w2 + b; n.label = 'n'
e = (2*n).exp()
o = (e-1) / (e+1)
o.label= 'o'




o.backward()
draw_dot(o)
